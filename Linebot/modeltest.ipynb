# %%
import cv2
import numpy as np
import os
import tensorflow as tf # 您的程式碼似乎使用 TensorFlow，所以在此匯入

MODEL_PATH = 'best_potato_model.keras'
model = tf.keras.models.load_model(MODEL_PATH)

# --- 請先在此區域進行設定 ---

# 假設您的模型和圖片尺寸已經定義好了
# 如果沒有，請取消以下註解並設定
# from tensorflow.keras.models import load_model
# model = load_model('your_model.h5') # 載入您訓練好的模型
# IMAGE_SIZE = (224, 224) # 設定模型輸入的圖片尺寸
IMAGE_SIZE = (224, 224)
# 指定包含所有圖片的資料夾路徑
folder_path = '../for_test/N/' # 請將 'for_test' 替換成您的資料夾名稱

# --- 主要處理邏輯 ---

# 檢查指定的路徑是否存在且是一個資料夾
if not os.path.isdir(folder_path):
    print(f"錯誤：找不到資料夾 '{folder_path}'")
else:
    # 取得資料夾中所有檔案的名稱
    all_files = os.listdir(folder_path)
    
    # 篩選出圖片檔案 (可以根據需求增加或修改附檔名)
    image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']
    image_files = [f for f in all_files if os.path.splitext(f)[1].lower() in image_extensions]

    if not image_files:
        print(f"在 '{folder_path}' 資料夾中找不到任何支援的圖片檔案。")
    else:
        print(f"在 '{folder_path}' 中找到 {len(image_files)} 張圖片，開始進行分析...\n")

        # 遍歷每一張圖片
        for image_name in image_files:
            # 組合出完整的圖片檔案路徑
            img_path = os.path.join(folder_path, image_name)
            
            # --- 以下是您原本的處理邏輯，放入迴圈中 ---
            
            # 載入一張圖片
            img = cv2.imread(img_path)

            # 檢查圖片是否成功載入
            if img is None:
                print(f"警告：無法讀取圖片 '{img_path}'，將跳過此檔案。\n")
                continue # 繼續處理下一張圖片
            
            print(f"--- 正在分析: {image_name} ---")

            # 調整圖片大小並轉換顏色空間
            img = cv2.resize(img, IMAGE_SIZE)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # 轉換為 RGB
            img_array = tf.expand_dims(img, 0) # 為模型預測建立一個 batch

            # 進行預測
            prediction = model.predict(img_array)
            score = prediction[0][0]

            # 顯示結果
            if score > 0.5:
                print(f"這顆馬鈴薯已發芽的機率是: {100 * score:.2f}%\n")
            else:
                print(f"這顆馬鈴薯未發芽的機率是: {100 * (1 - score):.2f}%\n")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 在 '../for_test/N/' 中找到 58 張圖片，開始進行分析...
#
# --- 正在分析: agriculture-72254_640.jpg ---
# 1/1 [==============================] - 4s 4s/step
# 這顆馬鈴薯未發芽的機率是: 98.89%
#
# --- 正在分析: agriculture-72255_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.82%
#
# --- 正在分析: appetite-1238323_640.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯未發芽的機率是: 99.05%
#
# --- 正在分析: eat-4239509_640.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯未發芽的機率是: 76.83%
#
# --- 正在分析: fresh-4868198_640.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯未發芽的機率是: 99.71%
#
# --- 正在分析: fresh-potato-2145499_640.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯未發芽的機率是: 99.67%
#
# --- 正在分析: heart-1625834_640.jpg ---
# 1/1 [==============================] - 0s 26ms/step
# 這顆馬鈴薯未發芽的機率是: 100.00%
#
# --- 正在分析: ladybug-1595857_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: papa-criolla-3432646_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 60.66%
#
# --- 正在分析: potato-1422580_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 97.88%
#
# --- 正在分析: potato-1475521_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.92%
#
# --- 正在分析: potato-1569659_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.97%
#
# --- 正在分析: potato-1569661_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.83%
#
# --- 正在分析: potato-2277455_640.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯未發芽的機率是: 68.05%
#
# --- 正在分析: potato-2982894_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 94.75%
#
# --- 正在分析: potato-3342842_640.jpg ---
# 1/1 [==============================] - 0s 19ms/step
# 這顆馬鈴薯未發芽的機率是: 97.79%
#
# --- 正在分析: potato-3429379_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 62.68%
#
# --- 正在分析: potato-3431841_640.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯未發芽的機率是: 94.55%
#
# --- 正在分析: potato-3440360_640.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯未發芽的機率是: 98.67%
#
# --- 正在分析: potato-3646642_640.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯未發芽的機率是: 99.68%
#
# --- 正在分析: potato-3859166_640.jpg ---
# 1/1 [==============================] - 0s 26ms/step
# 這顆馬鈴薯未發芽的機率是: 99.98%
#
# --- 正在分析: potato-4381403_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 51.49%
#
# --- 正在分析: potato-5318958_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.73%
#
# --- 正在分析: potato-6351899_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 99.46%
#
# --- 正在分析: potato-7372777_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 99.77%
#
# --- 正在分析: potato-954019_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯已發芽的機率是: 89.32%
#
# --- 正在分析: potato-fire-2735364_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 87.52%
#
# --- 正在分析: potatoes-1183623_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 99.24%
#
# --- 正在分析: potatoes-1509375_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 83.79%
#
# --- 正在分析: potatoes-1585060_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 93.71%
#
# --- 正在分析: potatoes-1637280_640.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 91.78%
#
# --- 正在分析: potatoes-1640362_640.jpg ---
# 1/1 [==============================] - 0s 25ms/step
# 這顆馬鈴薯未發芽的機率是: 99.93%
#
# --- 正在分析: potatoes-179471_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.45%
#
# --- 正在分析: potatoes-2046524_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: potatoes-3548847_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 73.75%
#
# --- 正在分析: potatoes-3665728_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 99.90%
#
# --- 正在分析: potatoes-3727958_640.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯未發芽的機率是: 80.18%
#
# --- 正在分析: potatoes-411975_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 99.82%
#
# --- 正在分析: potatoes-4330587_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 94.70%
#
# --- 正在分析: potatoes-448613_640.jpg ---
# 1/1 [==============================] - 0s 26ms/step
# 這顆馬鈴薯未發芽的機率是: 99.90%
#
# --- 正在分析: potatoes-501134_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 99.99%
#
# --- 正在分析: potatoes-5031508_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 58.03%
#
# --- 正在分析: potatoes-5371706_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 71.68%
#
# --- 正在分析: potatoes-6980000_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.96%
#
# --- 正在分析: potatoes-7495_640.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯未發芽的機率是: 99.36%
#
# --- 正在分析: potatoes-7498_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 99.14%
#
# --- 正在分析: potatoes-8474361_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 83.78%
#
# --- 正在分析: potatoes-888585_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 70.49%
#
# --- 正在分析: potatoes-965508_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 99.65%
#
# --- 正在分析: potatos-1141657_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 98.80%
#
# --- 正在分析: test1.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 99.82%
#
# --- 正在分析: test5.jpg ---
# 1/1 [==============================] - 0s 19ms/step
# 這顆馬鈴薯未發芽的機率是: 99.21%
#
# --- 正在分析: test6.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯未發芽的機率是: 99.98%
#
# --- 正在分析: test7.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 99.80%
#
# --- 正在分析: test8.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 83.79%
#
# --- 正在分析: vegetable-5323268_640.jpg ---
# 1/1 [==============================] - 0s 19ms/step
# 這顆馬鈴薯未發芽的機率是: 89.39%
#
# --- 正在分析: vegetable-6720516_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯未發芽的機率是: 98.53%
#
# --- 正在分析: vegetables-1707600_640.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯未發芽的機率是: 99.99%

# %%
import cv2
import numpy as np
import os
import tensorflow as tf # 您的程式碼似乎使用 TensorFlow，所以在此匯入

MODEL_PATH = 'best_potato_model.keras'
model = tf.keras.models.load_model(MODEL_PATH)

# --- 請先在此區域進行設定 ---

# 假設您的模型和圖片尺寸已經定義好了
# 如果沒有，請取消以下註解並設定
# from tensorflow.keras.models import load_model
# model = load_model('your_model.h5') # 載入您訓練好的模型
# IMAGE_SIZE = (224, 224) # 設定模型輸入的圖片尺寸
IMAGE_SIZE = (224, 224)
# 指定包含所有圖片的資料夾路徑
folder_path = '../for_test/S/' # 請將 'for_test' 替換成您的資料夾名稱

# --- 主要處理邏輯 ---

# 檢查指定的路徑是否存在且是一個資料夾
if not os.path.isdir(folder_path):
    print(f"錯誤：找不到資料夾 '{folder_path}'")
else:
    # 取得資料夾中所有檔案的名稱
    all_files = os.listdir(folder_path)
    
    # 篩選出圖片檔案 (可以根據需求增加或修改附檔名)
    image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']
    image_files = [f for f in all_files if os.path.splitext(f)[1].lower() in image_extensions]

    if not image_files:
        print(f"在 '{folder_path}' 資料夾中找不到任何支援的圖片檔案。")
    else:
        print(f"在 '{folder_path}' 中找到 {len(image_files)} 張圖片，開始進行分析...\n")

        # 遍歷每一張圖片
        for image_name in image_files:
            # 組合出完整的圖片檔案路徑
            img_path = os.path.join(folder_path, image_name)
            
            # --- 以下是您原本的處理邏輯，放入迴圈中 ---
            
            # 載入一張圖片
            img = cv2.imread(img_path)

            # 檢查圖片是否成功載入
            if img is None:
                print(f"警告：無法讀取圖片 '{img_path}'，將跳過此檔案。\n")
                continue # 繼續處理下一張圖片
            
            print(f"--- 正在分析: {image_name} ---")

            # 調整圖片大小並轉換顏色空間
            img = cv2.resize(img, IMAGE_SIZE)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # 轉換為 RGB
            img_array = tf.expand_dims(img, 0) # 為模型預測建立一個 batch

            # 進行預測
            prediction = model.predict(img_array)
            score = prediction[0][0]

            # 顯示結果
            if score > 0.5:
                print(f"這顆馬鈴薯已發芽的機率是: {100 * score:.2f}%\n")
            else:
                print(f"這顆馬鈴薯未發芽的機率是: {100 * (1 - score):.2f}%\n")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 在 '../for_test/S/' 中找到 50 張圖片，開始進行分析...
#
# --- 正在分析: 53135_0.jpg ---
# 1/1 [==============================] - 6s 6s/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: GREEN.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: GREEN02.jpg ---
# 1/1 [==============================] - 0s 28ms/step
# 這顆馬鈴薯未發芽的機率是: 97.52%
#
# --- 正在分析: GREEN03.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 89.97%
#
# --- 正在分析: imgi_11_potato-chtting-prior-to-planting-out.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_11_seed-potatoes-chitting-in-egg-box-on-white.jpg ---
# 1/1 [==============================] - 0s 33ms/step
# 這顆馬鈴薯已發芽的機率是: 99.94%
#
# --- 正在分析: imgi_13_top-view-of-old-box-with-sackcloth-and-pile-of-sprouted-potatoes-in-it.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 99.99%
#
# --- 正在分析: imgi_14_old-potato-bulbs-with-young-sprouts-ready-for-planting.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_14_sprouted-potatoes.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_15_raw-sprouted-ugly-potato-isolated-in-wooden-board-healthy-vegetable-food-concept.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_17_nylon-sack-sprouted-potatoes.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_19_plants-potatoes-for-new-season.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_20_plants-potatoes-for-new-season.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯已發芽的機率是: 81.51%
#
# --- 正在分析: imgi_20_sprouted-seed-potatoes-with-sprouts.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 97.17%
#
# --- 正在分析: imgi_21_potato-tubers-with-sprouted-sprouts.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_222_potato-3971660_640.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_22_plants-potatoes-for-new-season.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 97.95%
#
# --- 正在分析: imgi_24_potatoes-with-small-sprouts-in-a-plastic-jar.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_28_sprouted-potatoes.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_29_germinated-potato-close-up-shot.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_31_potato-seeds-growing.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_35_germinated-sweet-potato-isolated-on-white-background.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_37_chitting-potatoes.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_38_setting-epicure-potatoes-in-a-pot-container-gardening.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_42_farming-cultivation-agriculture-and-vegetables-concept.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 99.96%
#
# --- 正在分析: imgi_42_plants-potatoes-for-new-season.jpg ---
# 1/1 [==============================] - 0s 26ms/step
# 這顆馬鈴薯已發芽的機率是: 99.99%
#
# --- 正在分析: imgi_44_hand-planting-potato-tuber-into-the-ground.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_48_chitting-potatos.jpg ---
# 1/1 [==============================] - 0s 26ms/step
# 這顆馬鈴薯已發芽的機率是: 99.77%
#
# --- 正在分析: imgi_50_germinated-potato-and-onion.jpg ---
# 1/1 [==============================] - 0s 24ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_52_potato-with-sprouts-isolated-on-a-white-background.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_53_sweet-potatoes-sprouting.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 99.96%
#
# --- 正在分析: imgi_53_ugly-potatoes-that-have-been-sprouting.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 99.97%
#
# --- 正在分析: imgi_55_old-potato-sprouting-with-a-close-up-of-the-sprouts.jpg ---
# 1/1 [==============================] - 0s 26ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_56_seed-organic-potatoes-eight-sprouted-tubers-in-a-plastic-container.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 99.88%
#
# --- 正在分析: imgi_58_farming-cultivation-agriculture-and-care-of-vegetables-concept.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_60_sprouted-raw-orange-color-old-sweet-potato.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_61_side-of-sweet-potato-sprout-isolated-on-white-background-red-sweet-potatoes-sprout.jpg ---
# 1/1 [==============================] - 0s 19ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_62_chitted-potatoes-growing-in-a-wooden-rustic-crate.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 99.99%
#
# --- 正在分析: imgi_62_turning-these-sweet-potatoes-into-plants.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_63_potato-tubers-with-sprouted-sprouts-isolated-on-a-white-free-space-for-text.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_7_potato-tubers-planting-into-the-ground-early-spring-preparations-for-the-garden-season.jpg ---
# 1/1 [==============================] - 0s 23ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_8_planting-potato-tubers-in-the-soil-early-spring-preparation-for-the-gardening-season.jpg ---
# 1/1 [==============================] - 0s 22ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_8_sprouted-potatoes-wooden.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_9_sprouted-potato-tubers-in-hand-close-up-spoiled-vegetables.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: imgi_9_sprouting-potato.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: potatos-3633414_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 87.51%
#
# --- 正在分析: potatos-3633421_640.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯未發芽的機率是: 95.68%
#
# --- 正在分析: test2.jpg ---
# 1/1 [==============================] - 0s 20ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: test3.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
#
# --- 正在分析: test4.jpg ---
# 1/1 [==============================] - 0s 21ms/step
# 這顆馬鈴薯已發芽的機率是: 100.00%
